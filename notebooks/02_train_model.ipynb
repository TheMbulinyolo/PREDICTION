# %%
import pandas as pd

# %%
df = pd.read_csv("../data/processed/paris_appart_clean_01.csv")

# %%
y = df["prix_m2"]

# %%
x = df[
    ["Surface reelle bati",
    "Nombre pieces principales",
    "arrondissement"
    ]
]
